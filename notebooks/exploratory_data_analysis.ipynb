# %%
import sys
from pathlib import Path

# Set root folder (one level above notebooks/) to sys.path
root = Path().resolve().parent
sys.path.append(str(root))

# %%
import pandas as pd

pd.set_option("display.max_rows", None)

# %%
import pandas as pd

from src.load_data import load_data

file_path = "../data/raw/constituencies_dataset.csv"

df = load_data(file_path)

# %%
from src.eda.data_type import data_type

data_type(df)
# Out:
# constituency                        str
# year                              int64
# swing                           float64
# majority                        float64
# region                              str
# ethnic_homogeneity              float64
# median_age                        int64
# degree                          float64
# a_level                         float64
# gcse                            float64
# single                          float64
# homeowner                       float64
# student                         float64
# long_term_unemp                 float64
# routine_work                    float64
# semi_routine_work               float64
# intermediate_occupations        float64
# low_manager                     float64
# high_manager                    float64
# pubs                              int64
# pub_closures                      int64
# deprivation_rank                float64
# lsoa_most_deprived_decile       float64
# income_deprivation_rank         float64
# employment_deprivation_rank     float64
# education_deprivation_rank      float64
# health_deprivation_rank         float64
# crime_deprivation_rank          float64
# housing_deprivation_rank        float64
# environment_deprivation_rank    float64
# deprived_households             float64
# mean_weekly_wage_ft             float64
# mean_weekly_wage_pt             float64
# median_weekly_wage_ft           float64
# median_weekly_wage_pt           float64
# cv_weekly_wage                  float64
# first_decile_ft_weekly_wage     float64
# ft_jobs                         float64
# pt_jobs                         float64
# mean_hourly_wage_ft             float64
# mean_hourly_wage_pt             float64
# median_hourly_wage_ft           float64
# median_hourly_wage_pt           float64
# cv_hourly_wage                  float64
# first_decile_hourly_wage        float64
# median_hours_worked _ft         float64
# mean_hours_worked _ft           float64
# median_hours_worked _pt         float64
# mean_hours_worked _pt           float64
# population                      float64
# young                           float64
# old                             float64
# no_ch                           float64
# gas_ch                          float64
# electric_ch                     float64
# oil_ch                          float64
# solid_fuel_ch                   float64
# multiple_ch                     float64
# inv_majority                    float64
# last_election                     int64
# last_votes                      float64
# last_electorate                 float64
# last_turnout                    float64
# last_party                          str
# electorate                      float64
# conservative                      int64
# labour                            int64
# lib_dem                           int64
# ukip                              int64
# green                             int64
# 2010                              int64
# 2015                              int64
# 2017                              int64
# 2019                              int64
# last_majority                   float64
# votes                           float64
# margin                              str
# last_margin                         str
# last_government                   int64
# area                            float64
# density                             str
# dtype: object

# %%
from src.eda.missing_values import missing_values

missing_values(df)
# Out:
# constituency                      0
# year                              0
# swing                             4
# majority                          4
# region                            4
# ethnic_homogeneity                0
# median_age                        0
# degree                            0
# a_level                           0
# gcse                              0
# single                            0
# homeowner                         0
# student                           0
# long_term_unemp                   0
# routine_work                      0
# semi_routine_work                 0
# intermediate_occupations          0
# low_manager                       0
# high_manager                      0
# pubs                              0
# pub_closures                      0
# deprivation_rank                 41
# lsoa_most_deprived_decile        40
# income_deprivation_rank          40
# employment_deprivation_rank      40
# education_deprivation_rank       40
# health_deprivation_rank          40
# crime_deprivation_rank           40
# housing_deprivation_rank         40
# environment_deprivation_rank     40
# deprived_households               0
# mean_weekly_wage_ft               7
# mean_weekly_wage_pt              31
# median_weekly_wage_ft             6
# median_weekly_wage_pt           180
# cv_weekly_wage                    4
# first_decile_ft_weekly_wage      62
# ft_jobs                           4
# pt_jobs                          17
# mean_hourly_wage_ft               7
# mean_hourly_wage_pt              28
# median_hourly_wage_ft             6
# median_hourly_wage_pt            36
# cv_hourly_wage                    4
# first_decile_hourly_wage         69
# median_hours_worked _ft           4
# mean_hours_worked _ft             4
# median_hours_worked _pt          73
# mean_hours_worked _pt             4
# population                        3
# young                             3
# old                               3
# no_ch                             0
# gas_ch                            0
# electric_ch                       0
# oil_ch                            0
# solid_fuel_ch                     0
# multiple_ch                       0
# inv_majority                      4
# last_election                     0
# last_votes                        4
# last_electorate                   4
# last_turnout                      4
# last_party                        4
# electorate                        4
# conservative                      0
# labour                            0
# lib_dem                           0
# ukip                              0
# green                             0
# 2010                              0
# 2015                              0
# 2017                              0
# 2019                              0
# last_majority                     4
# votes                             4
# margin                            0
# last_margin                       0
# last_government                   0
# area                              4
# density                           0
# dtype: int64
